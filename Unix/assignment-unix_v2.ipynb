# %% [markdown]
# # Assignment: Unix
#
# ### Wouter Zorgdrager and Georgios Gousios

# %% [markdown]
# As we have seen during the lecture, the Unix command line is extremely
# versatile. This comes at a cost: you need to know which tool is suitable for the
# job or to build it. For this assignment, you will have to use a Unix command line
# (i.e. in the course's VM, a Mac or Ubuntu for Windows)
# to accomplish the indicated tasks. Not all tools you
# will need are readily available in the default installation of Xubuntu that we
# are using in the course. You need to search online (or implement!) for
# the appropriate tools and command line options.
#
# _Note_: To develop and run those commands in Jupyter, you need to install the
# [Bash kernel](https://github.com/takluyver/bash_kernel). Alternatively, you
# can create a file where you paste all programs/pipelines, print it and upload
# it to the assignment directory.
#
# There **120** points to collect. To get a 10, you need **110**.

# %% [markdown]
# ## Shell programming

# %% [markdown]
# **Q1 (10 points)** Write a pipeline that converts (recursively!) a directory
# structure full of `.wav` files to `.mp3`s.

# %%
#Works but not in CPM
#cd /home/bigdata/Downloads/assignment_1/
find . -type f -name *.wav | xargs -P 2 -I {} lame {}

#find . -type f -name '*.wav' -print0 | while read -d '' -r file; do 
#    ffmpeg -i "$file" -n -acodec libmp3lame -ab 128k "${file%.wav}.mp3" < /dev/null
#done

# %% [markdown]
# **Q2 (10 points)** Write a program that given a directory structure of text files, it
# prints the 10 most common words in those files (across all files).
#
# The output should look like this (example is for 3 most common items):
#
# ``
# 5 most_common_word
# 2 less_common_word
# 1 least_common_word
# ``

# %%
#-----CORRECT-----
find . -type f -name "*.txt" | xargs cat | tr ' ' '\n' | sort | uniq -c | sort -nr | head -10

# %% [markdown]
# **Q3 (10 points)** Given this
# [dataset](https://drive.google.com/file/d/1HYkiUFb_NKw4BWXSOvjgtw0jnjF4eA2s/view?usp=sharing)
# (which you will also be using later on), write a program that obtains the star
# count, watcher count and number of forks for first 10 repositories from the GitHub API.
# The output must look like the following:
#
# ```
# url,stars,watchers,forks
# https://api.github.com/repos/8d8d/Think.Admin,0,0,0
# https://api.github.com/repos/971638267/RetrofitAndRxjavaforRecyclerview,12,12,3
# https://api.github.com/repos/9alsacelost/greenDAO,0,0,0
# https://api.github.com/repos/a1265137718/ZoomHeader,0,0,0
# https://api.github.com/repos/12345678/NonExistingRepo,,,
# ```
#
# **Note** Make sure you use this path for the csv file: `repositories.csv` otherwise auto-grading will fail.
#
# **Warning** The GitHub API requires authentication, otherwise it is limited to 60 requests per hour. Make sure you setup [an OAuth key](https://developer.github.com/v3/#oauth2-token-sent-in-a-header) and use this key for doing the requests. After the assignment deadline, you can remove it. _If you fail to submit a solution including a key, the grading will fail_

# %%
#TODO

# %% [markdown]
# **Q4 (10 points)** Write a program that downloads all JPEG pictures in a web
# page. JPEG pictures are identified by the extensions `*.jpg` and `*.jpeg`.
# Your program must accept the URL to process as an argument. For example:
#
# ```bash
# $ jpegdl https://www.nu.nl
# [...]
# $ ls
# zi7xo0pa6h6x_std320.jpg
# hsnxkcyat176_std320.jpg
# [...]
# ```

# %%
#Works but not correct in CPM
#cd /home/bigdata/Downloads/assignment_1/pictures_from_websites/
function jpegdl() {
    wget -nd -r --level=1 -A .jpg,.jpeg $1
}

jpegdl https://www.nu.nl

# %% [markdown]
# **Q5 (10 points)** All Unix systems have a
# [dictionary file](https://en.wikipedia.org/wiki/Words_(Unix)) residing under
# `/usr/share/dict/words` or `/usr/dict/words`. Use it to implement a (rudimentary)
# spellchecker. Your spellchecker should read a file named `foo.txt` and print
# a list all the words in the document to be checked that are not in the dictionary.
# An example usage session can be seen below.
#
# ```bash
# $ cat foo.txt
# I am a nicelly formatted sentence,
# but I contain errors.
#
# $ cat foo.txt | spellchecker
# nicelly
# formated
# ```

# %%
#Works but not correct in CPM
#cd /home/bigdata/Downloads/assignment_1/text_files/
function spellchecker() {
     tr -d ',' | tr -d '.' | grep -o "\S*" | grep -xvFf /usr/share/dict/words
}

cat foo.txt | spellchecker
# Out:
# nicelly
# hav
# eror
# mongoel

# %% [markdown]
# **Q6 (10 points)** Given [this repository](https://github.com/SERG-Delft/jpacman-framework)
# at commit [05681455d905586f940e0e00e](https://github.com/SERG-Delft/jpacman-framework/commit/05681455d905586f940e0e00ed05f34266332ae9), find the sizes for all versions of all test files (assume that all test files are under `src/test/java`). The output must look like the following:
#
# ```
# blob_id blob_path size_in_bytes
# ```
#
# for example:
#
# ```
# da14c3975e src/test/java/nl/tudelft/jpacman/npc/ghost/NavigationTest.java 165
# 1fbe0d836d src/test/java/nl/tudelft/jpacman/sprite/SpriteTest.java 108
# 3bde982975 src/test/java/nl/tudelft/jpacman/sprite/SpriteTest.java 108
# 6286792e43 src/test/java/nl/tudelft/jpacman/sprite/SpriteTest.java 110
# ```
#
# A blob in Git represents a file version.

# %%
#TODO

# %% [markdown]
# ## Data processing

# %% [markdown]
# For the assignments in this section, we use the following [dataset](https://drive.google.com/file/d/1HYkiUFb_NKw4BWXSOvjgtw0jnjF4eA2s/view?usp=sharing) containing repositories.
#
# Write pipelines to calculate answers to the following questions:
#
# _Note:_ Use `"repositories.csv"` as filename, otherwise automatic grading will fail.

# %% [markdown]
# **Q7 (10 points)** Count the number of repositories written in `Java`.

# %%
#-----CORRECT-----
cd /home/bigdata/datasets/
awk -F ',' '{print$5}' repositories.csv | sort | uniq -c | grep -w Java | tr -dc '0-9'

# %% [markdown]
# **Q8 (10 points)** How many repositories were forked _and_ written in PHP?

# %%
#-----CORRECT-----
cd /home/bigdata/datasets/

awk -F "\"*,\"*" '{print $5","$7}' repositories.csv | grep -w PHP | grep -v NULL | wc -l

# %% [markdown]
# **Q9 (10 points)** Which `owner_id` owns most repositories?

# %%
#-----CORRECT-----
#Gives broken pipe error but works.
cd /home/bigdata/datasets/

awk -F ',' '{print$3}' repositories.csv | sort | uniq -c | sort -nr | head -1 | cut -d ' ' -f 8

# %% [markdown]
# **Q10 (10 points)**  Which repositories are created between `01-01-2017` and `24-03-2017` (both inclusive)? Print the names.

# %%
#Works but now in CPM
cd /home/bigdata/datasets/
awk -F "\"*,\"*" '{print $4" "$6}' repositories.csv | cut -d ' ' -f 1,2 | sort -k2 -n | grep -v name | sed -n '/2017-01-01/,/2017-03-25/{/2017-03-25/d; p}' | cut -d ' ' -f 1
# Out:
# 100-Days-Of-Code
# 133862-kekstagram
# 1st-Year-Comp-SCI-Project
# -
# 2017-Hestia-Server
# 236140-mishka
# 2869
# 2nd-manda
# 30-Days-of-Python
# 4a-isi3-tp2-2016-2017-groupe-2-delorme-kasprzyk
# 8-cph-network
# a11y.css
# acacia
# accountgo
# AES
# aframe-proxy-controls
# agenda-mapas
# Agile
# aima-pseudocode
# AIUIProductDemo
# Algorithms-in-Python
# aliyun-openapi-net-sdk
# analytics-dashboard
# ananthc.github.io
# AndoPrime
# ANDROID
# Android-Bootstrap
# AndroidChat
# android-dev-sources
# Android-Experiments--Hindering_Forensics-
# android_forder_01
# AndroidNote
# Android-Pay
# Android_Session7Assignment4
# AndroidSunshineClone
# AndroidTutorialForBeginners
# android-Ultra-Pull-To-Refresh
# angular
# AngularJSAuthentication
# angular-legacy-sortablejs
# angular-training
# AnotherThreadVR
# any-video
# api-lb
# apiRestSlim
# apt-analysis
# arc
# arcadetanks
# arkep
# asd-d-tugas-2-tomlomn
# ASNE
# aspnetcore-restapi
# AspNet.Security.OAuth.Providers
# ASP-Opdrachten
# assign3
# assignment-2017-1
# astro_t
# aurora-gateway
# autohispanoadmin
# awesome
# awesome-android-ui
# aws-sdk-php-zf2
# axle-zsim-nvmain
# azure-ml
# azure-powershell-docs
# BaiduMapDemo
# baseAdapter
# BaseRecyclerViewAdapterHelper
# bashbunny-payloads
# Basic
# BeamLight
# Become-A-Full-Stack-Web-Developer
# bem_markingup
# BetaVuew
# Big-Data-Analytics-and-Application---Envisager
# big_data_proyecto1
# BigDL
# Billy-Goat
# binux-tools
# bitcore-lib
# BlockCanaryEx
# BMASpinningLabel
# bodymovin
# bookstore
# bootstrap
# bootstrap
# bootstrap-modeltranslation
# bounswe2017group8
# btchip-signing-tools
# BuildAppOpencart
# bulkV1
# Cachet
# caffe
# caffe
# Cake.Gem
# Calculator-with-C-programming
# carbon-kernel
# Carpooling
# CarWash
# Casino_Virtual
# cdc-ionic-geolocation
# cefet-web-ninjas
# cefet-web-ninjas
# ceph-on-mesos
# cesium
# C-Exercises
# challenge-3-DreaAn
# charls
# charts_d3_v4
# chatik
# cheatsheet
# check-ssh-connect
# chhs-prototype
# chromium-infra
# churchwellington
# cidre
# CIFAR
# circbuf
# cling
# clojure-tutorial
# CodacyTest
# Code_Tips
# coffeetime
# collective-intelligence
# column-sortable
# compass
# CompetitiveSudoku
# Computer-Science-Controlled-Assessment-June-2016
# confirm-quit
# container
# conTesk2
# cooking-webapp
# Corrupt
# coursera-cluster_analysis
# CPE369
# CPU_Design
# cqbzOpenGLrigid
# cropper
# CRTest
# CS221-OOP2SY2016-17-Final-Projects
# CS261Assignment2
# cs329e-idb
# CS35L
# CSCE452_P2
# cschool-test-gendo
# CSE_1002
# cssninja
# ctechnology_erpnext
# cuke
# curryWurst
# Cusjo_Prod_Template
# cv-kelompok-workshop
# dab-cmdline
# DanilPractice
# darknet
# database
# datasharing
# datasharing
# dateparser
# datepicker
# db
# DB_A5
# ddPCM
# DeckRocket
# DeepCognitiveHierarchy
# deeplearning4j
# deep-qa
# Deep-Semantic-Similarity-Model
# DeepVideoAnalytics
# demo
# Demo
# DemoFaceRecognize
# demos
# deneme
# deployx
# destiny
# developer-roadmap
# developer-roadmap
# devportfolio-template
# DiagrammeR-docs
# Dibz
# dictator1
# dieting-plan
# Digital-Imagination
# digital_march_2
# distance-of-time
# DistClassify
# distributed-tcp-server
# div
# djangoBlog
# dlhttpc
# DocCentral
# docker-1
# docker-build-slave
# docker-odoo
# docker-php-pm
# docker-timemachine
# docubricksViewer
# Document-Management-System
# docute-iframe
# DodoDB
# donation_example
# doorkeeper-mongodb
# dreams
# DrifterGame
# drupal-console-book
# dry-validation
# ds
# dune
# dynamic-knapsack-problem
# E2E_VSCOMBranch_Dynamic
# Earnest
# easy-browser-cosmicjs
# easyctf-2017-writeups
# EasyLine
# ECollege
# educational
# edu-tratu
# edX-6.00.2x-Introduction-to-Computational-Thinking-and-Data-Science
# effectivealtruism
# endavant_deps
# enemyFrames
# Enigma
# EpubCFI
# Event-Extraction
# evw-ffs
# experiences
# ExportImageSOI
# extruder
# fable-suave-scaffold
# facebook_sticker_extract
# Fbb
# feedya
# fellowship-of-the-dom-plasticman2k
# fengari
# fernflower
# feYqb.github.io
# file
# find-elm-dependencies
# Flatabulous
# FlexBoxLayout
# FLIC-Analysis
# flight-manual.atom.io
# FloatingActionButton
# floobits-tests
# flux2-client
# flv.js
# fp-jargon-zh
# FPS-GAME-CPP
# frappe
# FRC2017
# FRC2017Steamworks
# FreeWifi
# Frigga
# Froglanders
# front-end-course
# full-stack-resources
# fundamentals-diagnostic
# FXAS21002C_Arduino_Library
# Gabbler
# GAM376
# ganasoft-meteor
# GeekPlatform
# GENCSR
# generated-pac-scripts
# generateid-server
# generator-jhipster
# gensim
# gentle-intro
# gerrit
# github
# gitkills
# git-rocks
# gitroot
# Git-Test2
# gl-node-training
# gl-utils
# go-btrfs
# go_command_tutorial
# gollum-demo
# gonetdotnet
# govuk_single_page_pdk
# greenDAO
# GreenSock-JS
# Guam-1_888_883-7055-United-Airlines-Booking-Numbe
# guess-game
# gulp-tobase64
# h2o-3
# hashids.php
# haw_html
# hbuddy-gateway
# hearthstack
# hello
# hello-world
# hello-world
# hello-world
# hello-world
# hello-world
# Hello_world
# hello_world_c
# helloworldphonegap
# hell-world
# hexo-theme-material
# Hinderest
# hive
# homeworking-landingpage2
# Hosts
# hotfunction_masnum_wave
# htmla
# html-issue-bot-9000-cb-gh-000
# htwg-bigdata
# Huawei_LiteOS_Kernel
# hybris_mentoring_sergei
# iCoAP
# IDAndBankCard
# IDCardRecognition
# IFE-2017
# IGListKit
# IIM_swift_intro
# image
# image
# immunio-xss-fuzzer
# inan
# inclusive-parents
# incorporation-information
# incubator-rocketmq
# Inf-122-Final-Project
# INFO-246-13.FA16
# InjectedDLL
# insight
# inspinia
# Integron_Modelling
# Intro-to-JS
# Inverse-effectiveness-paper
# iosched
# ios-decal-lab1
# iPhone_app_practice
# iPitch
# ISS-226-4
# jameschen
# JamsuniCodeScan
# japan-map
# java8-the-missing-tutorial
# javaConfig
# javacv
# JavaHomeTasks
# JavaLearning
# javascript-intro-to-functions-lab-js-intro-000
# jekyll-theme-materialize
# jetbrains-cask-bot
# JFastText
# jitsi-meet
# jjsbit_helpdesk
# JobCreator
# jobgenerator
# JobMate
# JohannesFog
# JpopupSelect
# jqfree
# jQuery-EasyUI
# jquery-qrcode
# js-cookie
# jwt-demo
# K9-MailClient
# Kaggle-Rainfall-Prediction
# KanbamBoard
# Keras
# keyformproject
# Keys
# KPI
# krile
# KUIKeyboard
# KYAnimatedPageControl
# laarid_package_debian-mesa
# labgrid
# la-loupe-0217-wiigle
# language-and-literature-admin
# language-ejs
# languageLearningAppDocumentation
# lapin
# LaravelBaseAcl
# laravel-feature
# larry.bot
# latihan-3-gcpd-DennyChrisna
# layer
# lda2vec
# learning
# LearningNotes
# LearningPython
# LearnOpenSource
# learn-travis
# LearnWeb
# leetcode
# Leshell-Luu.github.io
# lged
# Library_DataStructure
# libsrtp
# libwebsockets
# link-grammar
# ll2016
# LMS_LibraryManagementSystem
# LoadMore
# loam_velodyne
# LockTest
# lodge
# LoggingData
# logico
# loop
# lora
# LotteryGaming
# lowCoverAssembly
# LQRWeChat
# lsd-slam_paper_translation
# Lua-x32
# lunch
# lv-232
# Lychee
# Lyra
# lzh
# machine-learning-cheat-sheet
# main
# mainFile
# makeen
# makinuk.github.io
# maluiza.github.io
# mammoth.js
# ManageSlack
# map
# markdown-cheatsheet
# marketo-rest-python
# mastercracker
# MaterialDesign
# matoghelse
# MatrixRunner
# mbed-coap
# MCFNL
# MCMS
# mcuoneclipse
# mean-lab
# mean_mytasklist
# MeasurementItemFrontEnd
# medical-app
# medium-articles
# melb_2017s1_watch_jade
# men-project
# mestocasticos
# Mestre-Ivo
# MeuProjeto
# micro-rollbar
# MIDI.js
# midterm
# MillerZachary_CSC5_Spring2017
# mindandhand.github.io
# miniBoardLearn
# minimal-mistakes
# mixmax
# MJExtension
# mmap_allocator
# MMMarkdown
# MMM-MovieListings
# mobile
# MockupsWithPS
# mon-week2d
# Morituri
# Motorola68K_Disassembler
# movies-for-hackers
# mpd_client_with_rust
# mplinks
# MultiPhotoPicker
# multi-threaded-server-TCP-RMI
# Muse
# mybootstrap
# my-contri-module
# MyJava
# Mytest
# MyTools
# Narvis_writing
# NCHU_WEB_HW3
# NDKDemo
# netfox
# NettyRpc-1
# neural_artistic_style
# neural-playground
# neural-style
# nextcloud-server
# nltk-trainer
# node
# nodejs_rcx
# Node-Shell-Workshop
# ns-dev-days-demo
# objc-automatic
# objective-c-style-guide
# obs-studio
# ohmygold.github.io
# one
# one_plus_2
# onesql
# OnlineTest
# Oosterhesselen
# OpenRealty
# opensource.guide
# op-rabbit
# optimizing-react
# order-client
# orm-jr-1
# os_ex2
# os-net-config
# OS_P4
# OurNewsAdmin
# oyster_card_challenge-
# palma
# PanelProject
# paper_soccer
# pathfinder-beginner
# patternfly-react
# PDF-export-sketch-plugin
# personal-projects
# petclinic
# pHash
# phooning.github.io
# php-semver
# pin-generator
# pkg-epoptes
# Plastico-Shibaq
# Platform
# PlaygroundWithCarthage
# plomberie
# plugin-intellij
# PocketMine-MP
# Poetance.github.io
# POJ_Problems
# Pollen-Neutralization-System
# portfolio
# portfolio_site
# pose-hg-train
# PostReader
# PowerShellDefense
# Powershell-SlackBot
# Practica1
# Practice-3
# prem
# PricesEquilibriumAndroidExperiment
# PrismIssueTest
# PrjLSW
# prm.api
# proc-bridge
# profiles-db
# progressive-image.js
# project42
# project_gA
# project-noir
# projectRun-frontend
# projectyatzy
# projet_html
# projet_pendu
# ProjNet4GeoAPI
# proprietary_vendor_samsung
# Proyecto-JDBC---Moleculas
# Proyecto_JPS_Tiempos
# prueba-Pizano
# pry-rails
# PSoC-4-BLE
# psychopy
# puppet-duo_unix
# puppet-logstashforwarder
# pycrumbs
# PyLDA
# pymicro
# pyneural
# Python
# QA-Cinemas-Cohort5-Team1
# qdp-lapack
# QNews
# quest1
# quickadmin
# rabbit-on-k8s-standalone
# radar-js-api
# radix-cli
# raincatcher-demo-protractor
# raincatcher-workorder-angular
# rainforest
# Raisal
# Raj
# randoop
# react-affix
# react-booking
# React-demo
# react-kanban
# react-native.cn
# react-native-image-crop-picker
# react-native-iShiWuPai
# react-native-navigation
# react-pwa-guide-kit
# react-todo
# react-tutorial-project
# react-webpack-rails-tutorial
# reading
# ReadingJournal
# README
# real-connect
# rebase-conflict-hard-varture
# recipes
# recipes-post
# Recommendation-NLP
# redis-in-action
# ReduxTodoApp
# regestration
# rendertoy
# requirejs
# ResourcePack.DNNCE.08.00.00.pt-BR
# retrofit
# RetrofitAndRxjavaforRecyclerview
# reusable-react
# reversi-react
# riak
# richbeam
# rich-purple-web
# RobustInsertCodeTools
# rocketmq-client4cpp-linux
# RockETS-Basestation
# rr-api
# RTRootNavigationController
# Ruby_k59
# rulerp.github.io
# runc
# rust-render-engine
# ruziRestaurantPartners
# rwd-1
# S
# s3io
# Sales
# sass-guidelines
# saturn-pademu
# schul-cloud.github.io
# scrapy
# SDWebImage
# seal
# SEC
# second
# secondhomework
# Security
# SecurityInput
# segmentation
# SeniorProject
# sensor-de-lluvia
# sf-angular-drag-and-drop-lists
# shaderRender
# shadowsocks-heroku
# SharpFont
# ShenzhenCTB
# shop-phone
# shopping-cart-reactjs-redux
# shortener
# shrub_sapflow
# sicp
# sicp
# siddhantakaumudi
# SimpleServer
# Simplistic-RSS-Demo-master4
# sinatra-hello-world-basics-cb-000
# si_rep5
# sitecore-foundation-codegeneration-composition
# sj_rep2
# skills-based-javascript-intro-to-flow-control-bootcamp-prep-000
# skynet
# Slic3r
# slicer
# SlickGrid
# smhw
# smooth-scroll
# Snarl
# SnoozeTabs
# SOCRAT-issues
# sologue
# SoundShapesBox2d_HKGen
# source
# SpaceRock
# spark-anaconda
# speeduino
# SpinningCubes
# Spring
# spring-boot
# springBoot
# springboot-docker-swarm
# SpringBoot_REST_API
# spring-boot-samples
# spring-cloud-microservice-examples
# SpringMVCHelloWord
# SqlStreamStore
# sqlutil
# squealy
# StanfordNgMLcourse
# star-wars-responsive-challenge
# STOC-Machine-projects
# streaming-readings
# struts-examples
# StrutsHoneypot
# study
# styleguide
# suue
# svetopotolok
# SwiftySound
# SWProject
# sylius-sitemap-bundle
# symantec-cwg-2017
# SyncUp
# Tabchi-1
# TDPOO
# team3
# TEMPRUN
# TensorFlow-Examples
# tesla
# test1.github.io
# Test
# test
# Test
# Testando
# testbench-core
# Tester
# testgit
# testGIT
# TestingRepo
# testingrg
# TestRepo
# test_webpack
# textlibrary
# TFFRCNN
# theticketresale.github.io
# thingsboard
# Think.Admin
# Think.Admin
# TicTacToe
# tic-tac-toe
# TiendaRopa
# TigerML
# TimeBeatTest
# timetracker
# TimLiu-iOS
# tinker-manager
# tinyTurtleUnit10Starter
# titatoggle
# tornado
# TP2_INF8405_Version_2_1
# trailhead-code-samples
# travis-broken-example
# Trial
# tsar
# ttt-9-play-loop-cb-gh-000
# TUG-W4NilCVAOJUmpMoD3LzHP1Rdu
# TuoManPrivateCloud
# tvla_recurring
# TweetBot
# twitter-client
# twitterclonekickstarter
# twitter_nlp
# UberTools
# uboot-hyphop-mizy
# uniform-cms
# untitled
# Update-basics
# uphere-web
# uploader
# UVC-revised-for-suppress-intraframe-data-corruptioin
# vanilla-docs-theme
# vcr
# vectorSurveyingServices
# VeloRhyPlayer
# verify-web
# Verkefni6
# Viberr-webapp
# video.js
# .vim
# vim-markdown
# viossvc
# visual-recognition-nodejs
# vlayout
# vlc-android
# voyager
# VRTK
# vscode
# vscode-tips-and-tricks
# vue-form-generator
# w3af
# webgl-lessons
# webpack-react-hot-module-reloading
# Website
# Website-Launch-Checklist-for-Web-Designers
# WEBTEK-LAB
# webvr-boilerplate
# web-with-python-proman-notimplementederror
# WeiXinRecordedDemo
# Win_Form_Data_Transfer
# wingo
# Wiznet_5500
# WMDragView
# wonpago
# wordpress-hybrid-client
# ws
# wttr.in
# Xblog
# xia-blog
# xZoom
# yii2-starter-kit
# yogiq-back-end
# zabbix-docker
# zeppelin
# zeus
# ZKJ-LSX
# ZoomHeader
# ZRPC

# %% [markdown]
# **Q11 (10 points)**: Print the `10` most used programming languages sorted on popularity.

# %%
#-----CORRECT-----
cd /home/bigdata/datasets/
awk -F ',' '{print$5}' repositories.csv | sort | uniq -c | sort -nr | grep -v NULL | head -10 | tr -d '0-9' | tr -d ' '

# %% [markdown]
# **Q12 (10 points)**: Print the `username` of the owners whose repositories are deleted.
#
# _Hint_: Use the url field.

# %%
#TODO
